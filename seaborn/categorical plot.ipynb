# %% [markdown]
# # Seaborn: Categorical Plots

# %%
import seaborn as sns
import numpy as np

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
sns.set_style('darkgrid')

# %%
# Bar plot
# X axis as category and y as numerical value
sns.barplot(x='sex',y='total_bill',data=tips)

# %%
sns.barplot(x='sex',y='total_bill',data=tips,estimator=np.std)

# %%
# Count plot
sns.countplot(x='sex', data=tips)

# %%
# Box plot
# Dots are ouliers
sns.boxplot(x='day',y='total_bill',data=tips)

# %%
sns.boxplot(x='day',y='total_bill',data=tips,hue='smoker')

# %%
# Violin plots
sns.violinplot(x='day',y='total_bill',data=tips,split=True)

# %%
sns.violinplot(x='day',y='total_bill',data=tips,hue='sex',split=True)

# %%
#Strip plot
sns.stripplot(x='day',y='total_bill',data=tips, jitter=True)

# %%
sns.stripplot(x='day',y='total_bill',data=tips,hue='sex',split=True)
# Out:
# /home/ai/anaconda3/lib/python3.7/site-packages/seaborn/categorical.py:2784: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
#Swarm plot
sns.swarmplot(x='day',y='total_bill',data=tips)

# %%
sns.violinplot(x='day',y='total_bill',data=tips)
sns.swarmplot(x='day',y='total_bill',data=tips,color='black')

# %%
# Cat plot
sns.catplot(x='day',y='total_bill',data=tips,kind='bar')
